# %%
import folium
import pandas as pd

# %%
map1 = folium.Map(location= , zoom_start= )
# 지도 불러오기
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
#마커 하나 추가하기
folium.Marker(
        location = ,
        popup = ,
    )

#지도 불러오기
map1

# %%
# 데이터 불러오기
data = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vStkMyBpK1su7mhg7XulFmGzb56esA01IOzHM_NJisCuRXJTLM6CTbtFAI_bEkkNFhcPoRcMEL4HVh6/pub?gid=1252880174&single=true&output=csv")

# 상위 5개 데이터 확인
data.head()
# Out:
#       no    연도        관할기관  ...                          주소   Latitude   Longitude
# 0  37864  2021  국회공직자윤리위원회  ...  경기도 남양주시 화도읍 가곡리 산 55-43번지  37.692367  127.302111
# 1  37865  2021  국회공직자윤리위원회  ...  경기도 남양주시 화도읍 가곡리 산 55-70번지  37.692378  127.302622
# 2  37866  2021  국회공직자윤리위원회  ...          경기도 시흥시 장현동 산 20번지  37.378831  126.795759
# 3  37867  2021  국회공직자윤리위원회  ...        경기도 시흥시 장현동 산 39-2번지  37.374353  126.801356
# 4  37887  2021  국회공직자윤리위원회  ...  인천광역시 강화군 내가면 고천리 1339-3번지  37.710995  126.402962
#
# [5 rows x 21 columns]

# %%
# 데이터 프레임 행 선택
data
# Out:
# 37.6923674

# %%
# 데이터 첫번째 행으로 마커 찍기
folium.Marker(
    location = [ , ]  ,
    popup = 
).add_to(map1)
#지도 확인하기
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# 데이터 두번째 행으로 마커 찍기

# %%
len(data)
# Out:
# 164

# %%
# 데이터의 위경도 좌표로 지도에 마커를 찍어본다.
# 바로 위에서 찍은 마커는 필요없으므로 새로운 지도(map2)를 만들고 마커를 찍는다

map2 = folium.Map(location = [37.5655723,126.9774113], zoom_start=8) 
# 위의 map1 만드는 코드와 동일

for i in range(0, len(data)) :
    folium.Marker(
        location = [data.iloc[i]['Latitude'], data.iloc[i]['Longitude']],
        popup = data.iloc[i]['이름'],
    ).add_to(map2)

map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
