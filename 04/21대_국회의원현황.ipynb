# %%
name_url = 'https://www.assembly.go.kr/assm/memact/congressman/memCond/memCondListAjax.do?s_poly_cd=&s_dept_cd=&s_dtl_no=&s_elected_method=&s_up_orig_cd=&s_dw_orig_cd=&s_mem_nm=&currentPage=1&movePageNum=&rowPerPage=300'

xpath_tag = 'dl'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('a'):
    print(link.text.strip(), link.get('href'))
# Out:
# 뉴스스탠드 바로가기 #newsstand
# 주제별캐스트 바로가기 #themecast
# 타임스퀘어 바로가기 #timesquare
# 쇼핑캐스트 바로가기 #shopcast
# 로그인 바로가기 #account
#  https://whale.naver.com/details/darkmode?=main&wpid=RydDy7
# 다운로드 https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe
# 네이버 /
# 네이버를 시작페이지로 https://help.naver.com/support/welcomePage/guide.help
# 쥬니어네이버 https://jr.naver.com
# 해피빈 https://happybean.naver.com
# 한글 입력기 #
# 자동완성 레이어 #
# 전체삭제 #
# @txt@ #
# 삭제 #
# 도움말 https://help.naver.com/support/alias/search/word/word_29.naver
# 도움말 https://help.naver.com/support/alias/search/word/word_29.naver
# 도움말 https://help.naver.com/support/service/main.help?serviceNo=605&categoryNo=1991
# 자동저장 끄기 #
# @5@회차 당첨번호
#
# 추첨 @13@.지급기한 1년
#
#
#
#
# @6@@7@@8@@9@@10@@11@@12@ #
# @14@
#
# @txt@@currency@
#
# @8@(@9@%)
#
#
#
# @6@원 #
# @txt@
#
# @7@, @message@
#
#
#
#
#
# @7@
# @8@° #
# @txt@
#
# @5@
#
#
#
# 바로가기 @5@
# @txt@ #
# 추가 #
# @txt@ #
# 추가 #
# @query@ @intend@ #
# 추가 #
# 자세히보기 #
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen(name_url)
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all(xpath_tag):
    print(link.text.strip(), link.get('href'))
# Out:
# 강기윤
#
# 											(姜起潤)
#
#     			KANG GIYUN
#
#
#
#
#
#
# 재선
# 경남 창원시성산구 None
# 강대식
#
# 											(姜大植)
#
#     			KANG DAESIK
#
#
#
#
#
#
# 초선
# 대구 동구을 None
# 강득구
#
# 											(姜得求)
#
#     			KANG DEUKGU
#
#
#
#
#
#
# 초선
# 경기 안양시만안구 None
# 강민국
#
# 											(姜旻局)
#
#     			KANG MINKUK
#
#
#
#
#
#
# 초선
# 경남 진주시을 None
# 강민정
#
# 											(姜旼姃)
#
#     			KANG MINJUNG
#
#
#
#
#
#
# 초선
# 비례대표 None
# 강병원
#
# 											(姜炳遠)
#
#     			KANG BYUNGWON
#
#
#
#
#
#
# 재선
# 서울 은평구을 None
# 강선우
#
# 											(姜仙祐)
#
#     			KANG SUNWOO
#
#
#
#
#
#
# 초선
# 서울 강서구갑 None
# 강은미
#
# 											(姜恩美)
#
#     			KANG EUNMI
#
#
#
#
#
#
# 초선
# 비례대표 None
# 강준현
#
# 											(康準鉉)
#
#     			KANG JUNHYEON
#
#
#
#
#
#
# 초선
# 세종특별자치시을 None
# 강훈식
#
# 											(姜勳植)
#
#     			KANG HOONSIK
#
#
#
#
#
#
# 재선
# 충남 아산시을 None
# 고민정
#
# 											(高旼廷)
#
#     			KO MINJUNG
#
#
#
#
#
#
# 초선
# 서울 광진구을 None
# 고영인
#
# 											(高永寅)
#
#     			KO YOUNGIN
#
#
#
#
#
#
# 초선
# 경기 안산시단원구갑 None
# 고용진
#
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

import sys
sys.stdout = open('output.txt','w')

html = urlopen(name_url)
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all(xpath_tag):
    print(link.text.split())
# Out:
# ['강기윤', '(姜起潤)', 'KANG', 'GIYUN', '재선', '경남', '창원시성산구']
# ['강대식', '(姜大植)', 'KANG', 'DAESIK', '초선', '대구', '동구을']
# ['강득구', '(姜得求)', 'KANG', 'DEUKGU', '초선', '경기', '안양시만안구']
# ['강민국', '(姜旻局)', 'KANG', 'MINKUK', '초선', '경남', '진주시을']
# ['강민정', '(姜旼姃)', 'KANG', 'MINJUNG', '초선', '비례대표']
# ['강병원', '(姜炳遠)', 'KANG', 'BYUNGWON', '재선', '서울', '은평구을']
# ['강선우', '(姜仙祐)', 'KANG', 'SUNWOO', '초선', '서울', '강서구갑']
# ['강은미', '(姜恩美)', 'KANG', 'EUNMI', '초선', '비례대표']
# ['강준현', '(康準鉉)', 'KANG', 'JUNHYEON', '초선', '세종특별자치시을']
# ['강훈식', '(姜勳植)', 'KANG', 'HOONSIK', '재선', '충남', '아산시을']
# ['고민정', '(高旼廷)', 'KO', 'MINJUNG', '초선', '서울', '광진구을']
# ['고영인', '(高永寅)', 'KO', 'YOUNGIN', '초선', '경기', '안산시단원구갑']
# ['고용진', '(高榕禛)', 'KOH', 'YONGJIN', '재선', '서울', '노원구갑']
# ['곽상도', '(郭尙道)', 'KWAK', 'SANGDO', '재선', '대구', '중구남구']
# ['구자근', '(具滋根)', 'KU', 'JAKEUN', '초선', '경북', '구미시갑']
# ['권명호', '(權明浩)', 'KWON', 'MYUNGHO', '초선', '울산', '동구']
# ['권성동', '(權性東)', 'KWEON', 'SEONGDONG', '4선', '강원', '강릉시']
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

import sys
sys.stdout = open('output.txt','w')

html = urlopen(name_url)
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all(xpath_tag):
    print(link.text.split())
