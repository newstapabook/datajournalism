# %%
import pandas as pd

# %%
waset_data = pd.read_csv("https://data.newstapa.org/datasets/%EA%B0%80%EC%A7%9C%ED%95%99%ED%9A%8C-WASET-%ED%95%9C%EA%B5%AD-%EA%B4%80%EB%A0%A8-%EB%8D%B0%EC%9D%B4%ED%84%B0/files/waset-20180727.csv", sep=',')

# %%
waset_data.shape
# Out:
# (2441, 8)

# %%
waset_data.columns
# Out:
# Index(['no', '분류', '중복', 'Institution', 'Title', '저자', 'Year', 'Pdf Link'], dtype='object')

# %%
waset_data.head(10)
# Out:
#    no          분류  ...  Year                                           Pdf Link
# 0   1  Periodical  ...  2007  https://waset.org/publications/10964/2d-and-3d...
# 1   2    Abstract  ...  2016  https://waset.org/pdf/books/?id=52549&pageNumb...
# 2   3    Abstract  ...  2015  https://waset.org/pdf/books/?id=26766&pageNumb...
# 3   4  Periodical  ...  2015  https://waset.org/publications/10000960/a-fram...
# 4   5    Abstract  ...  2016  https://waset.org/pdf/books/?id=52542&pageNumb...
# 5   6    Abstract  ...  2015  https://waset.org/pdf/books/?id=49942&pageNumb...
# 6   7    Abstract  ...  2015  https://waset.org/pdf/books/?id=21239&pageNumb...
# 7   8  Periodical  ...  2013  https://waset.org/publications/2934/a-review-o...
# 8   9    Abstract  ...  2015  https://waset.org/pdf/books/?id=34233&pageNumb...
# 9  10    Abstract  ...  2017  https://waset.org/pdf/books/?id=69640&pageNumb...
#
# [10 rows x 8 columns]

# %%
import numpy as np

pd.pivot_table(waset_data, index = ['Institution'], columns = None)
# Out:
#                                                            Year  ...        중복
# Institution                                                      ...
# Academy of Korean Studies                           2017.000000  ...  0.000000
# Agency for Defense Development                      2015.000000  ...  0.333333
# Ajou University                                     2015.212121  ...  0.121212
# Andong National University                          2016.500000  ...  0.000000
# Animal and Plant Quarantine Agency                  2015.833333  ...  0.166667
# Anyang University                                   2017.000000  ...  0.500000
# Asan Medical Center                                 2015.000000  ...  0.000000
# Bison Medical                                       2016.000000  ...  0.500000
# Buan Water Quality                                  2016.000000  ...  0.000000
# Busan National University                           2007.000000  ...  0.000000
# Busan University of Foreign Studies                 2017.000000  ...  0.000000
# Busan Water Authority                               2016.000000  ...  0.000000
# CAD/CAM Research Center                             2008.000000  ...  0.000000
# CHA university                                      2017.000000  ...  0.000000
# Catholic Kwandong University                        2017.000000  ...  0.000000
# Catholic Medical Center                             2017.000000  ...  0.000000
# Catholic University of Daegu                        2014.666667  ...  0.000000
# Chang Minwoo Structural Consultants                 2016.000000  ...  0.000000
# Changwon National University                        2018.000000  ...  0.000000
# Cheongju University                                 2012.000000  ...  0.000000
# Chodang University                                  2017.500000  ...  0.000000
# Chonbuk National University                         2015.075949  ...  0.240506
# Chonnam National University                         2014.720000  ...  0.120000
# Chosun University                                   2014.885714  ...  0.228571
# Chung-Ang University                                2015.111111  ...  0.222222
# Chungbuk National University                        2014.652174  ...  0.130435
# Chungju University                                  2011.000000  ...  0.000000
# Chungnam National University                        2015.428571  ...  0.142857
# DAUM Engineering Co., Ltd.                          2017.200000  ...  0.400000
# DGMIF                                               2017.000000  ...  0.000000
# ...                                                         ...  ...       ...
# Seoul National University                           2015.544643  ...  0.107143
# Seoul National University of Science and Techno...  2015.105263  ...  0.315789
# Seoul Theological University                        2008.000000  ...  0.000000
# Seoul Women's University                            2016.000000  ...  0.000000
# Silla University                                    2014.500000  ...  0.000000
# Sinjang Elementary School                           2016.000000  ...  0.000000
# Sogang University                                   2015.285714  ...  0.000000
# Soonchunhyang Univeristy                            2014.333333  ...  0.000000
# Soongsil University                                 2012.457143  ...  0.114286
# Sun Moon University                                 2017.000000  ...  0.000000
# Sunchon National University                         2016.000000  ...  0.000000
# Sungkyunkwan University                             2014.650000  ...  0.191667
# Sungshin Women's University                         2016.000000  ...  0.000000
# The Catholic Univeristy of Korea                    2015.333333  ...  0.000000
# Tongmyong University                                2014.000000  ...  0.500000
# U2 System Inc.                                      2017.000000  ...  0.000000
# UNIENS Co. Ltd.                                     2015.500000  ...  0.500000
# Ulsan College                                       2016.000000  ...  0.500000
# Ulsan National Institute of Science and Technology  2014.500000  ...  0.000000
# University of Seoul                                 2015.689655  ...  0.241379
# University of Suwon                                 2014.000000  ...  0.500000
# University of Ulsan                                 2015.120000  ...  0.120000
# Water Quality Institute, Busan Water Authority      2016.000000  ...  0.000000
# Wonkwang University                                 2015.000000  ...  0.000000
# Woongjin Energy Co.,Ltd.                            2013.000000  ...  0.000000
# Woosong University                                  2015.000000  ...  0.000000
# Yeungnam University                                 2014.829268  ...  0.170732
# Yongin Mental Hospital                              2015.000000  ...  0.000000
# Yonsei University                                   2014.923077  ...  0.163462
# You & Green Korean Medical Clinic                   2016.000000  ...  0.000000
#
# [235 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'NanumBarunGothic'

# %%
fig, ax = plt.subplots(1,1, figsize = (6,10))
waset_data['Institution'].value_counts().head(40).plot.barh(
  ax=ax, zorder=3, fc='#444444')
ax.invert_yaxis()
ax.grid(zorder=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
